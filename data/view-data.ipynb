# %%
import pandas as pd
from pathlib import Path

# Optional: show all columns, wider display
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", 50)

# %%
# Path to the DB (works from data/ or repo root)
db_path = Path("photos_db.csv")
if not db_path.exists():
    db_path = Path("data/photos_db.csv")
df = pd.read_csv(db_path)

# print(f"Shape: {df.shape[0]} rows × {df.shape[1]} columns\n")
# df.head(10)

# %%
df
# Out:
#                     photo_id neighborhood_id neighborhood_name  \
# 0     20251209_125542_00_314       kinshicho         Kinshicho
# 1     20251209_125556_00_315       kinshicho         Kinshicho
# 2     20251209_125610_00_316       kinshicho         Kinshicho
# 3     20251209_125624_00_317       kinshicho         Kinshicho
# 4     20251209_125639_00_318       kinshicho         Kinshicho
# ...                      ...             ...               ...
# 1894  20251211_162653_00_387        jinbocho          Jinbocho
# 1895  20251211_162704_00_388        jinbocho          Jinbocho
# 1896  20251211_162715_00_389        jinbocho          Jinbocho
# 1897  20251211_162726_00_390        jinbocho          Jinbocho
# 1898  20251211_162737_00_391        jinbocho          Jinbocho
#
#      neighborhood_name_ja         lon        lat       ele        date  \
# 0                     錦糸町  139.813989  35.699024  5.749331  2025-12-09
# ...

# %%
# Quick summary: photos per neighborhood
df["neighborhood_name"].value_counts(dropna=False)

# %%
# Column types and non-null counts
df.info()
