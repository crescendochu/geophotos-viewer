# %%
import geopandas as gpd

# %%
# read the geojson file 
gdf = gpd.read_file("photos_db.geojson")
# Out:
# /Users/chuli/opt/anaconda3/envs/project-sidewalk/lib/python3.10/site-packages/pyogrio/geopandas.py:49: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   res = pd.to_datetime(ser, **datetime_kwargs)
# /Users/chuli/opt/anaconda3/envs/project-sidewalk/lib/python3.10/site-packages/pyogrio/geopandas.py:49: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   res = pd.to_datetime(ser, **datetime_kwargs)

# %%
gdf
# Out:
#                     photo_id                        filename  \
# 0     20251209_125542_00_314  IMG_20251209_125542_00_314.jpg
# 1     20251209_125556_00_315  IMG_20251209_125556_00_315.jpg
# 2     20251209_125610_00_316  IMG_20251209_125610_00_316.jpg
# 3     20251209_125624_00_317  IMG_20251209_125624_00_317.jpg
# 4     20251209_125639_00_318  IMG_20251209_125639_00_318.jpg
# ...                      ...                             ...
# 1827  20251211_161808_00_348  IMG_20251211_161808_00_348.jpg
# 1828  20251211_161819_00_349  IMG_20251211_161819_00_349.jpg
# 1829  20251211_161832_00_350  IMG_20251211_161832_00_350.jpg
# 1830  20251211_161843_00_351  IMG_20251211_161843_00_351.jpg
# 1831  20251211_161854_00_352  IMG_20251211_161854_00_352.jpg
#
#                                     folder  \
# 0     IMG_20251209_125542_314_343_INTERVAL
# 1     IMG_20251209_125542_314_343_INTERVAL
# 2     IMG_20251209_125542_314_343_INTERVAL
# 3     IMG_20251209_125542_314_343_INTERVAL
# ...
